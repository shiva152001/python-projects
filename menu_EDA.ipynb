# %% [markdown]
# <a href="https://colab.research.google.com/github/shiva152001/python-projects/blob/main/menu_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
with open('/content/menu.csv', 'r', encoding='latin-1') as f:
    contents = f.read()
df = pd.read_csv('/content/menu.csv', encoding='latin-1')
df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
df.shape
# Out:
# (260, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %%
df.columns
# Out:
# Index(['Category', 'Item', 'Serving Size', 'Calories', 'Calories from Fat',
#        'Total Fat', 'Total Fat (% Daily Value)', 'Saturated Fat',
#        'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#        'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#        'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)'],
#       dtype='object')

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df = df.drop('Trans Fat', axis=1)
df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Cholesterol  ...  Carbohydrates  \
# ...

# %%
df .drop_duplicates()
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# ...

# %%
df .drop_duplicates(inplace=True)
df .shape
# Out:
# (260, 23)

# %%
df.isnull().sum()*100/df .shape[0]
# Out:
# Category                         0.0
# Item                             0.0
# Serving Size                     0.0
# Calories                         0.0
# Calories from Fat                0.0
# Total Fat                        0.0
# Total Fat (% Daily Value)        0.0
# Saturated Fat                    0.0
# Saturated Fat (% Daily Value)    0.0
# Cholesterol                      0.0
# Cholesterol (% Daily Value)      0.0
# Sodium                           0.0
# Sodium (% Daily Value)           0.0
# Carbohydrates                    0.0
# Carbohydrates (% Daily Value)    0.0
# Dietary Fiber                    0.0
# Dietary Fiber (% Daily Value)    0.0
# Sugars                           0.0
# Protein                          0.0
# Vitamin A (% Daily Value)        0.0
# Vitamin C (% Daily Value)        0.0
# Calcium (% Daily Value)          0.0
# Iron (% Daily Value)             0.0
# dtype: float64

# %%
any_duplicates = df.duplicated().any()

print(any_duplicates)
# Out:
# False

# %%
num_duplicates = df.duplicated().sum()

print(num_duplicates)
# Out:
# 0

# %%
duplicate_rows = df[df.duplicated()]

print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [Category, Item, Serving Size, Calories, Calories from Fat, Total Fat, Total Fat (% Daily Value), Saturated Fat, Saturated Fat (% Daily Value), Cholesterol, Cholesterol (% Daily Value), Sodium, Sodium (% Daily Value), Carbohydrates, Carbohydrates (% Daily Value), Dietary Fiber, Dietary Fiber (% Daily Value), Sugars, Protein, Vitamin A (% Daily Value), Vitamin C (% Daily Value), Calcium (% Daily Value), Iron (% Daily Value)]
# Index: []
#
# [0 rows x 23 columns]

# %%
all_occurrences_duplicates = df[df.duplicated(keep=False)]

print(all_occurrences_duplicates)
# Out:
# Empty DataFrame
# Columns: [Category, Item, Serving Size, Calories, Calories from Fat, Total Fat, Total Fat (% Daily Value), Saturated Fat, Saturated Fat (% Daily Value), Cholesterol, Cholesterol (% Daily Value), Sodium, Sodium (% Daily Value), Carbohydrates, Carbohydrates (% Daily Value), Dietary Fiber, Dietary Fiber (% Daily Value), Sugars, Protein, Vitamin A (% Daily Value), Vitamin C (% Daily Value), Calcium (% Daily Value), Iron (% Daily Value)]
# Index: []
#
# [0 rows x 23 columns]

# %%
df_no_duplicates = df.drop_duplicates()

print(df_no_duplicates)
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# ...

# %%
df_no_duplicates.shape
# Out:
# (260, 23)

# %%
df['Category'].unique()
# Out:
# array(['Breakfast', 'Beef & Pork', 'Chicken & Fish', 'Salads',
#        'Snacks & Sides', 'Desserts', 'Beverages', 'Coffee & Tea',
#        'Smoothies & Shakes'], dtype=object)

# %%
df['Category'];df.isnull().sum()*100/df.shape[0]
# Out:
# Category                         0.0
# Item                             0.0
# Serving Size                     0.0
# Calories                         0.0
# Calories from Fat                0.0
# Total Fat                        0.0
# Total Fat (% Daily Value)        0.0
# Saturated Fat                    0.0
# Saturated Fat (% Daily Value)    0.0
# Cholesterol                      0.0
# Cholesterol (% Daily Value)      0.0
# Sodium                           0.0
# Sodium (% Daily Value)           0.0
# Carbohydrates                    0.0
# Carbohydrates (% Daily Value)    0.0
# Dietary Fiber                    0.0
# Dietary Fiber (% Daily Value)    0.0
# Sugars                           0.0
# Protein                          0.0
# Vitamin A (% Daily Value)        0.0
# Vitamin C (% Daily Value)        0.0
# Calcium (% Daily Value)          0.0
# Iron (% Daily Value)             0.0
# dtype: float64

# %%
df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Cholesterol  ...  Carbohydrates  \
# ...

# %% [markdown]
# # **DATA VISUALIZATION**

# %%
plt.figure(figsize=(14,5))
sns.countplot(x='Category', data=df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(14,5))
sns.countplot(x='Category', data=df, hue='Cholesterol')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(14,5))
sns.barplot(x='Category', y='Calories', data=df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(12,5))
sns.scatterplot(x='Category', y='Total Fat', data=df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(18,12))
sns.histplot(x='Category',data=df, hue='Sugars')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(18,12))
sns.histplot(x='Category',data=df, hue='Protein')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
